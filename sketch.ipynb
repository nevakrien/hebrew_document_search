# %%
import os
os.environ["HF_HUB_CACHE"] = "/media/user/8a594cab-20d9-43ef-8d0e-b60b5cf43462/huggingface_models/hub"
#https://huggingface.co/docs/transformers/installation?highlight=transformers_cache#cache-setup
#os.environ["HF_HOME"] = "/media/user/8a594cab-20d9-43ef-8d0e-b60b5cf43462/huggingface_models"
model_name="Norod78/hebrew-gpt_neo-xl"#'meta-llama/Llama-2-70b-chat-hf'

# %%
import faiss
from transformers import AutoTokenizer,AutoModelForCausalLM

# %%
tokenizer=AutoTokenizer.from_pretrained(model_name)

# %%
model=AutoModelForCausalLM.from_pretrained(model_name)#,cach_dir="/media/user/8a594cab-20d9-43ef-8d0e-b60b5cf43462/huggingface_models/hub")

# %%
model.to('cuda')
# Out:
# GPTNeoForCausalLM(
#   (transformer): GPTNeoModel(
#     (wte): Embedding(50257, 2048)
#     (wpe): Embedding(2048, 2048)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPTNeoBlock(
#         (ln_1): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTNeoAttention(
#           (attention): GPTNeoSelfAttention(
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#             (k_proj): Linear(in_features=2048, out_features=2048, bias=False)
#             (v_proj): Linear(in_features=2048, out_features=2048, bias=False)
#             (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#             (out_proj): Linear(in_features=2048, out_features=2048, bias=True)
#           )
#         )
#         (ln_2): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPTNeoMLP(
#           (c_fc): Linear(in_features=2048, out_features=8192, bias=True)
#           (c_proj): Linear(in_features=8192, out_features=2048, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=2048, out_features=50257, bias=False)
# )

# %%
prompt_text="אתה יכול להראות לי קוד C?"
encoded_prompt = tokenizer.encode(prompt_text, add_special_tokens=False, return_tensors="pt").to('cuda')

# %%
sample_outputs = model.generate(
    encoded_prompt,
    do_sample=True, 
    max_length=1000, 
    top_k=50, 
    top_p=0.95, 
    num_return_sequences=4
)

# %%
ans=tokenizer.batch_decode(sample_outputs)
ans
# Out:
# ['אתה יכול להראות לי קוד C?\nהיי יש לי בעיה עם הקוד אז אני לא יודע איך לשנות..\n\nנ נח net: אתה כותב כל יום? (משנ"ב)\nהייתי רוצה לקבל את זה במייל אבל לא בטוח שכדאי לך.\nאני כל הזמן מקבל את זה במייל, מה דעתך אולי אולי לשלוח לשם?\nשלום לכולם!\nאני רוצה לשאול אותכם שאלה.. אם יש את אותה בעיה אז האם אפשר להשתמש בזה בתור תשובה?\nאם כן, אז איך?\nאם אתם רוצים להשתמש בזה בתור תגובה אז איך עושים את זה?\nתודה רבה לכם\nאם לא אז תנסה לשלוח למייל (דרך הפייסבוק או דרך האתר https://www.facebook.com/tal.horayonel)\n\nעמוד ראשי _ התחבר או אם אינך עדיין רשום, הרשם בחינם.\nרוצים לקבל הודעה במייל בכל פעם שהבלוג שלי מתעדכן?\nאין סוף ליכלוך.\nזה ממש לא נעים.\nהייתי כותבת את זה אבל כנראה שלא הייתי צריכה כי אני כל כך סובלת.\nאז שוב תמשיכי לכתוב את כל מה שעולה לך לראש.\nאוהבת אותך ♥\nעל מנת להשתמש בכפתור אהבתי עליכם להיות מחוברים או להרשם.\n© כל הזכויות לתוכן המופיע בדף זה שייכות לMrs.Miss Mrs\n\nיש יופי בכולנו - בלוג איפור וטיפוח: פברואר 2012\nזה באמת יפה!\nאהבתי את האיפור\nוואו! איזה יופי!\nאני עדיין לא יכולה להפסיק\nגם אני מתלבטת אם הוא מתאים לי או לא :/\nתודה! אני חושבת שזה גם איפור שאהבתי בזמנו :-)\nאין כמו אמא!\nאיזה כייף לגלות שאת אוהבת איפור!!!\nשמחה שאת אוהבת :-)\nתודה רבה! גם לי הוא מזכיר את הסבתות (עם ציצים גדולים ;)\nרשומה חדשה יותר רשומה ישנה יותר דף הבית\nהירשם ל- תגובות לפרסום (Atom)\nחפש בבלוג זה\nרשומות פופולריות\nSkincare לשדרוגי איפור, עיניים ושפתיים.\nלמה כדאי לקנות את הקונסילר בארץ?\nאיך זה עובד?\nFA03 סקירת מוצר\nלמה כדאי לקנות את הקונסילר בארץ?\n3.7.17 - הקונצנזוס סביב מראה איפור - קונסילר\n1.7.17 - איך להתאפר כמו אודרי הפבורן?\nאני מזהירה מראש, הקונסילר הזה ממכר...\nמה צריך לעשות בשביל שהקונסילר יצליח?\nקונסילרים מכילים פיגמנטים, שתפקידם להעניק לעור מראה חי וזוהר. לכן, על מנת להשתמש נכון בקונסילר עלינו לדעת להשתמש בו בצורה הנכונה.\n2.7.17 - כל הדברים שרצית לדעת על מייקאפ\nמייקאפ הינו מוצר הנצרך בכל בית, ולכן חשוב לדעת עליו הכל. ריכזנו את כל מה שצריך לדעת כדי לדעת לאפר את עצמכן בצורה נכונה.\nעל מנת להשתמש בכפתור אהבתי עליכם להיות מחוברים או להרשם.\nבושם זה נחמד, אבל כשזה נוגע לבשמים - עדיף להשתמש בבושם עדין שלא יכביד ולא ישעמם.\nעל מנת להשתמש בכפתור אהבתי עליכם להיות מחוברים או להרשם.\nהבחורה הזו יודעת לעשות איפור!!!!!\nלשים לב מה היא משתמשת (למרות שאני לא רואה איפור שלה).\nהיא משתמשת במברשת מייקאפ. אני לא בטוחה שזה יעזור, אני משתמשת במברשת מייקאפ בשביל להסתיר אזורים בעייתיים כמו הקמטוטים סביב העיניים, אבל אין ספק שמייקאפ זה חלק בלתי נפרד מהמראה.\nשמתי לב שהמברשות של בובי בראון יותר מעודנות.\nאני מאמינה שמייקאפ זה מוצר הנצרך בכל בית.\nיש לי מייקאפ של בובי בראון, עם מברשת מייקאפ גדולה וצפופה.\nיש לי מברשת מייקאפ שטוחה (פחות קטנה ממברשת מייקאפ גדולה אחרת).\nאני משתמשת במברשת מייקאפ של מאק (האהובה עלי במיוחד).\nיש לי גם צללית של בובי בראון (שהיא יקרה באופן יחסי).\nהבעיה עם המברשת היא שהיא צולעת עם הקצה, ולכן, אני משתמשת במברשת מייקאפ קטנה (במקום במברשת פודרה גדולה).\nאני לא אוהבת את המברשות של מאק, כי הן גדולות עבורי (אני רגילה למברשות זולות יותר).\nהמברשת של בובי היא מברשת להנחת צלליות, ולכן אני משתמשת במברשת פודרה.\nיש לי מברשת הנחה גדולה של מאק (מס\' 172, אם אני זוכרת נכון...).\nאני לא אוהבת מברשת מייקאפ קטנה וצפופה.\nמבחינת גודל, אני משתמשת במברשת של מייקאפ פודרה (אם אני זוכרת נכון...)\nהמברשת שאני משתמשת בה היא מברשת מייקאפ של בובי בראון.\nאני משתמשת במברשת מייקאפ של',
#  'אתה יכול להראות לי קוד C?\nלא.\nלא, לא.\nאין לו שום קוד, אין לו כלום.\nמה הוא צריך?\nאני מתכוון, איך אני קורא את הקובץ שיש על ידי הקוד?\nהאם יש לך משהו כמו זה?\nמה יש על ידי קובץ?\nאם אתה לא עובד על זה, אל תדאג.\nבגלל זה כתבתי את זה.\nלא היה לי אותו.\nאז עכשיו אתה כן.\nהייתי רוצה להפגש איתך בפעם הבאה, כדי לדון על זה, ולתת לך קצת.\nאתה צריך להירשם, אני רוצה לדעת יותר.\nאבל מה אתה יכול לספר לי על האתר הזה?\nאיך זה עובד?\nכרגע אני לא יודע.\nמה אני יכול לדעת?\nזה באמת כל מה שאתה יודע?\nהאתר הוא לא לגמרי שלי.\nזה אומר שזה לא חוקי של.\nלמה אין לך?\nאני פשוט לא יודע.\nאתה יודע, בגלל שאתה לא רוצה אותי לעשות את כל זה, אני פשוט...\nאני הולך להתקשר, אם אתה רציני, אני הולך לחכות לך, אני אדבר איתך על כמה דברים, אני הולך לומר לך מה שאני הולך לעשות, ואז אתה צריך לענות לי על זה.\nלא, לא.\nטוב, אז אם יש לך מה לומר, זה יהיה נחמד.\nלא, אני פשוט רוצה לדעת יותר!\nזה האתר שלי.\nאני הולך להגיד לך מה קורה, ואני הולך לומר לך מה לעשות.\nמה אתה עושה?\nאני לא יודע שום דבר!\nזה לא אתר שלי.\nלא, לא, למה אתה לא יודע שום דבר?\nאנחנו לא הולכים לדבר על זה.\nאתם חושבים שאתם יודעים?\nאני הולך להגיד לך.\nאני אפרסם את הכל, אני הולך לתת לך איזה רעיון, אז אתה יכול להגיד לי מה אתה רוצה?\nאני רוצה לקנות.\nאתם חושבים שאתם יכולים לקנות את המוצר הזה?\nאתה צריך כסף בשביל זה?\nלא, אני לא יודע, פשוט...\nאני אתן לך כסף כדי לרכוש את זה.\nאז מי אתה?\nאני חבר שלך, אני יודע שאני יכול.\nלא, לא, אתה לא יכול.\nאני רוצה להיות חבר שלך, ואני יכול.\nאתה יודע, אתה לא אוהב אותי.\nזה לא עניין.\nאתה לא רוצה את זה, זה לא.\nאתה יודע...\nזה פשוט לא נכון.\nאתה חייב אותי לי, ואתם חייבים אותי בשביל זה?\nלא, אין לך את הזכות הזאת.\nאתה לא יכול לעשות את זה!\nזה היה ככה, אתה חייב לעזור לי!\nאני חייב אותך בחזרה!\nעכשיו אתה חייב לעשות את זה.\nכדי לעזור לי, או לא?\nמה אם אני לא יכול להיות חבר שלך?\nאתה חייב לעזור לי.\nמה אתה עושה עם זה?\nהאם זה לא נכון?\nאם לא תיתן לי את הכסף שלי, ולא תשאיר שום דבר, ואתה לא לעזור לי, זה יעזור לי יותר טוב.\nאני חייב לנסות, אני חייב להשיג את הכסף שלי.\nאני חייב למצוא חברים חדשים, זה משהו שאני רוצה.\nאתה יכול להיות חבר שלך.\nאני יכול להיות חבר שלך.\nאני לא יכול להיות חברים שלך.\nאתה לא יכול להיות חבר שלך.\nאתה לא יכול להיות חבר שלי.\nזה לא, זה לא.\nזו הסיבה שאני לא יכול.\nזה לא, זה לא.\nאני חייב את זה.\nוזה לא.  \nאני חייב למצוא דרך כדי לעזור לכם.\nאני חייב למצוא דרך לעזור לך.\nאני צריך, חבר שלי, אני צריך למצוא דרך לעזור לך!\nזה מה שאתה אומר?\nאני יכול לעזור לך, חבר שלי, אני יודע, אבל מה שאני לא יכול לעשות, זה לא אפשרי.\nאני יודע שאתה יכול, אבל אני לא יכול לעזור לך.\nאני לא יכול לעזור לך עם.\nאתה חייב לתת לי ללכת, וזה מה שאני צריך לעשות.\nתן לי לדבר.\nאז מה אתה עושה?\nאני אגיד לך בדיוק מה שאתה צריך.\nלמצוא דרך לעזור לך.\nאני צריך להשיג את הכסף שלי, ואני לא יכול לקבל אותו בחזרה.\nיש לי מספיק מהכסף שלי, אבל אני חייב למצוא דרך לעזור לך.\nאני צריך ללכת, חבר שלי, ללכת.\nיש לי מספיק.\nמה אתם עושים?\nבואו לראות אם יש לי את כל הכסף בחזרה.\nובכן, אתה באמת צריך כל מה שאתה צריך.\nאתה חייב לקבל את ההודעה.\nזה היה.\nיש לך את כל הכסף.  \nרק, אני חייב להיות בחיים.\nאני חייב לעשות את זה, חבר שלי, אם אני יכול.\nאני חייב להציל את החברים שלי.  \nאני חייב להציל את החברים שלי.\nזה מה שאתה עושה?\nבשביל כולנו.\nאני יכול לעזור לך.\nאני יכול לעזור לך',
#  'אתה יכול להראות לי קוד C?\nיש כאן קוד embed, אבל אני לא מבין אותו\nאולי תסביר לי?\nאם אתה רוצה למחוק את הקוד, אתה יכול לעשות זאת בלי קוד embed\nכלומר בלי הקוד.\nאם מישהו מנסה למחוק, אתה יכול לתת לו גישה לקוד או שאתה יכול לתת גישה לקוד שלי\nפשוט כדי שאני לא אמחק את הקוד\nאני לא מבין למה זה טוב.\nבינתיים, אם מישהו מבקש ממך גישה לקוד שלי, אתה חייב לתת לו גישה לקוד embed.\nאתה לא יכול לתת לו גישה לקוד שלך.\nאתה יכול רק לעזור לי.\nבבקשה.\nאת הקוד הזה צריך להיות פתוח לקריאה בלבד.\nאת הקוד הזה צריך להיות פתוח לקריאה בלבד.\nאני לא יכול לתת גישה לקוד שלי.\nאתה יכול לעזור לי למחוק את הקוד?\nבבקשה.\nבסדר.\nאני פשוט... אני לא מבין למה... אני לא מבין מה הקוד הזה עושה.\nזה כמו למחוק קוד.\nזה כמו למחוק קוד.\nזה כמו למחוק קוד.\nזה כמו למחוק קוד.\nזה כמו למחוק קוד.\nזה כמו למחוק קוד.\nזה כמו למחוק קוד.\nאם מישהו רוצה להשתמש בקוד הזה, אני אשמח מאוד אם יוכל לקבל אותו.\nבבקשה.\nאת הקוד הזה אני לא יכול לשלוח.\nאני פשוט לא רוצה לקבל אותו.\nאת הקוד הזה אני לא יכול לשלוח.\nאת הקוד הזה אני לא יכול לשלוח.\nאני יודע שאתה יכול לעזור לי, אבל הקוד הזה לא יהיה גלוי.\nאם אתה יודע את הקוד, תמצא אותו.\nאתה צריך גם להשתמש ב-IE כדי לראות למה הוא נועד, אבל אתה לא יכול לעשות זאת כאן.\nזה קוד embed.\nעכשיו זה הקוד embed, אז בוא נמחוק אותו.\nאתה יכול לקבל אותו?\nאני צריך למחוק אותו לפני שאני אמחק אותו.\nאת הקוד הזה אתה לא יכול לשלוח.\nאתה יכול, אבל אתה לא תמצא אותו.\nאתה צריך קודם למחוק אותו, כדי שהקוד יהיה גלוי.\nאם לא תמצא אותו, אתה לא תמצא אותו.\nיש לך מושג כמה זמן זה ייקח לי לכתוב את הקוד?\nבבקשה.\nאת הקוד הזה ניתן למחוק רק באמצעות הקוד הזה.\nאני לא מבין למה.\nמה שזה נותן זה גישה לכל קוד או קובץ embed.\nאם מישהו יכול להשתמש בו, אני אבטל אותו.\nההבדל היחיד בין זה לקוד embed הוא שאני לא יכול למחוק אותו.\nזה בקוד שלך.\nאני צריך לכתוב את הקוד הזה.\nאני לא יודע את הקוד הזה.\nלא יודע את הקוד הזה.\nיש לך מושג כמה זמן זה ייקח לי לכתוב את הקוד?\nבבקשה.\nאת הקוד הזה ניתן למחוק רק באמצעות הקוד הזה.\nאם מישהו רוצה להשתמש בקוד הזה, אני אשמח מאוד אם יוכל לקבל אותו.\nתודה.\nאבל אל תמכור את הקוד הזה למי שלא יודע למחוק.\nאם מישהו רוצה למכור את הקוד הזה, אני לא מוכר אותו לאדם שלא יודע למחוק אותו.\nאני לא אומר שלא אוכל למצוא אותו, אבל לא אני אקח על עצמי את האחריות למחוק את הקוד הזה.\nאין בעיה.\nאני אמשיך למחוק את הקוד.\nאולי יש לך רעיון טוב יותר...\nיש לי כמה רעיונות טובים.\nרעיון טוב... אולי אני אמשיך עם הקוד ואז אני אחזור ואמחק אותו.\nאת הקוד הזה יש למחוק באמצעות קוד embed.\nזה קוד embed.\nאני לא יכול למחוק אותו.\nאני יודע שתוכל למחוק את הקוד.\nאני אמשיך למחוק אותו.\nאני אמשיך למחוק אותו.\nזה הקוד הזה... אתה מבין?\nזה הקוד הזה.\nאני לא יכול למחוק אותו.\nאני לא יכול למחוק את הקוד.\nיש לך רעיון טוב יותר?\nטוב מאוד.  \nיש לי רעיון מצוין.\nזה קוד embed.\nזה קוד embed.\nאני לא יכול למחוק אותו.\nאולי תוכל לעזור לי.\nאני חושב שיש לי רעיון טוב.\nאתה באמת יכול למחוק את הקוד הזה.\nלא את הקוד הזה.\nאם מישהו מחפש קוד כזה, הוא יכול לחפש אותו גם ב-PHP.\nאם מישהו ירצה להשתמש בקוד הזה, הוא גם יכול לחפש אותו ב-PHP.\nאם מישהו ירצה להשתמש בקוד הזה, הוא גם יכול לחפש אותו ב-PHP.\nאם מישהו ירצה להשתמש בקוד הזה, הוא גם יכול למצוא אותו ב-PHP.\nאם אתה רוצה את הקוד הזה, אני רוצה אותו.\nאני רוצה שהוא יהיה גלוי.\nאם אתה רוצה שהוא יהיה גלוי, זה אומר שעליך לתת לי גישה לקוד הזה.\nזה קוד embed.\nאתה צריך לתת גישה.\nקוד',
#  'אתה יכול להראות לי קוד C?\nתודה לך, אבל אני לא יודע מה קוד C זה\nאני לא יודע מה זה\nתודה לך, אבל אני לא יודע מה זה, איך אני יכול להוסיף אותו?\nכדי להכניס קוד C, השתמש הקוד הבא:\nאני חושב שזה קוד:\nתודה לך, אבל לא יודע, איך אני יכול להוסיף קוד C?\nכדי להכניס קוד C, השתמש הקוד הבא:\nתודה לך, אבל לא יודע, איך אני יכול להוסיף קוד C?\nהתכוונת קוד C, אז למה אתה צריך להכניס קוד C אם הקוד C הוא קוד, גם?\nקוד C הוא קוד, אתה משתמש בו, לכן אני חושב שזה קוד, וזה מה שאני צריך.\nקוד C אמור להכניס קוד C, ולא צריך קוד C כדי להכניס קוד C, קוד C זה קוד, והכותרת שלו היא C, ולא, לא אמורים להיות קוד C, אלא אם זה קוד C, ואז זה קוד\nקוד C הוא קוד, והכותרת שלו היא C, ולא, לא אמורים להיות קוד C, אלא אם זה קוד C, ואז זה קוד.\nקוד C זה הקוד עצמו, כמו שאתה משתמש בו\nתודה לך, אבל אני לא יודע, איך אני יכול להוסיף קוד C\nקוד C זה קוד, ואם לא עושים מה שאמרתי, הקוד C לא מתאים לכזה קוד C, הוא לא קוד.\nאבל עדיין, כדי להוסיף קוד C, צריך לעשות קוד C, צריך להכניס קוד C. הקוד C הוא הקוד עצמו, הוא לא.\nהתכוונת קוד C, אז לא, הוא לא מתאים. אתה צריך להוסיף קוד C, כדי שזה יתאים לקוד ה-C, הוא צריך לעבוד.\nקוד C הוא קוד עצמו, כדי שזה יראה טוב.\nאם אתם רוצים שהוא יראה יפה, אז קוד C זה הקוד עצמו.\nקוד C זה הקוד עצמו, לכן אני חושב שזה הקוד, אבל לא צריך קוד C, אלא אם זה קוד C, ואז זה קוד C, ואם כן, אז זה קוד.\nקוד הוא קוד (איך שלא קוראים לזה).\nאם אתם רוצים שהוא יראה יפה, אז קוד C זה הקוד בעצמו.\nקוד זה קוד, זה קוד.\nקוד C הוא קוד עצמו, ולכן הוא קוד.\nקוד C זה הקוד עצמו, הוא לא.\nקוד הוא קוד עצמו, קוד C הוא קוד.\nקוד הוא קוד.\nקוד הוא קוד, לא כל קוד, לא כל פקודה.\n\nעסקים _ כלכלה _ הלוואות _ כלכלה _ הלוואות לעסקים קטנים _ כלכלה _ הלוואות\nאתר אינטרנט מותאם לכל מכשיר (מחשב / מחשב שולחני, טאבלט / טלפון נייד), המותאם\nלתפוצת שיחות של 1G לשיחות בינלאומיות.\nהמערכת מבוססת על פלטפורמה של Microsoft.\nמערכת ניהול תורים, המאפשרת גישה לתיק הלקוחות,\nלכל חבר מועדון מכל מקום ובכל שעה.\nניתן להוסיף עד 2 מועדונים שונים.\nלמערכת ניהול תורים מספר מאפיינים ייחודיים:\nשליחת התראות על התראות, למייל או למכשיר הסלולרי.\nשליטה מלאה ב"שליטה מרחוק" לכל החברים במועדון.\nהוספת עד 2 מועדונים (2 מועדונים גדולים או 2 מועדונים קטנים)\nיכולת שליחה לכל הלקוחות בכל זמן או לכל הלקוחות (לכל החברים במועדון).\n\nמתכוני מנות ראשונות\nמתכוני דגים\nמתכונים דלי שומן\nמתכוני פסטה\nמתכוני ירקות\nמתכוני פשטידות\nמתכוני עוגות\nמתכוני משקאות\nמתכונים לראש השנה\nמתכונים לחנוכה\nמתכונים ליום העצמאות\nחדש על המדף\n[19 באוקטובר 2018] השבוע בענף היין 151: דרכו הארוכה של יקב רקנאטי לצפון והחגיגה של מיכאל בן יוסף יין\n[19 באוקטובר 2018] הפיציולו של ישראל לשנת 2018 והפיצה הטובה בעולם מסעדות\n[18 באוקטובר 2018] חדש מטירת צבי: נתחוני חזה עוף מנתח שלם אפויים וללא תוספים מלאכותיים חדש על המדף\n[18 באוקטובר 2018] צ\'ורוס לחנוכה מתכונים לחנוכה\n7 בנובמבר 2017 אורנה לב בשר ביתכתבות אורח, מדור אוכל\nבמסעדת "ברטי" השוכנת בכפר הרא"ה, ממשיכים לטפח את המטבח הישראלי. כחלק מאירועי"שבוע קולינרי"של עמותת לתת, יגיש השף אסף גרניט עם המנות החדשות גם מנה ראשונה. כל מה שצריך לדעת על מנה עיקרית\n25 ביוני 2018 אורנה לב בשר ביתכתבות אורח, מדור אוכל\nהמנות המסורתיות של המטבח האתיופי, בשילוב עם טכניקות הבישול המתקדמות, יצרו מתכונים רבים, שכדי ליהנות מהם גם בתקופת החורף חשוב לדעת כיצד לבשל. את המתכונים האלה מגיש השף ארז קומרובסקי עם המנות הקלאסיות של העדה, בשילוב עם המטבח המסורתי.\nהמסעדה, שתגיש לכם את מנות האתיופים האותנטיות עם מיטב מאכלי העדה, תיפתח ב-23 באוגוסט ותציע את המאכלים האתיופים האותנטיים שלה גם לקהל הישראלי. המנות יוגשו לצד משקה הבית רימונים צ\'יה, עם עוגיות']

# %%
print(ans[0])
# Out:
# אתה יכול להראות לי קוד C?
# היי יש לי בעיה עם הקוד אז אני לא יודע איך לשנות..
#
# נ נח net: אתה כותב כל יום? (משנ"ב)
# הייתי רוצה לקבל את זה במייל אבל לא בטוח שכדאי לך.
# אני כל הזמן מקבל את זה במייל, מה דעתך אולי אולי לשלוח לשם?
# שלום לכולם!
# אני רוצה לשאול אותכם שאלה.. אם יש את אותה בעיה אז האם אפשר להשתמש בזה בתור תשובה?
# אם כן, אז איך?
# אם אתם רוצים להשתמש בזה בתור תגובה אז איך עושים את זה?
# תודה רבה לכם
# אם לא אז תנסה לשלוח למייל (דרך הפייסבוק או דרך האתר https://www.facebook.com/tal.horayonel)
#
# עמוד ראשי _ התחבר או אם אינך עדיין רשום, הרשם בחינם.
# רוצים לקבל הודעה במייל בכל פעם שהבלוג שלי מתעדכן?
# אין סוף ליכלוך.
# זה ממש לא נעים.
# הייתי כותבת את זה אבל כנראה שלא הייתי צריכה כי אני כל כך סובלת.
# אז שוב תמשיכי לכתוב את כל מה שעולה לך לראש.
# אוהבת אותך ♥
# על מנת להשתמש בכפתור אהבתי עליכם להיות מחוברים או להרשם.
# © כל הזכויות לתוכן המופיע בדף זה שייכות לMrs.Miss Mrs
#
# יש יופי בכולנו - בלוג איפור וטיפוח: פברואר 2012
# זה באמת יפה!
# אהבתי את האיפור
# וואו! איזה יופי!
# אני עדיין לא יכולה להפסיק
# גם אני מתלבטת אם הוא מתאים לי או לא :/
# תודה! אני חושבת שזה גם איפור שאהבתי בזמנו :-)
# אין כמו אמא!
# איזה כייף לגלות שאת אוהבת איפור!!!
# שמחה שאת אוהבת :-)
# תודה רבה! גם לי הוא מזכיר את הסבתות (עם ציצים גדולים ;)
# רשומה חדשה יותר רשומה ישנה יותר דף הבית
# הירשם ל- תגובות לפרסום (Atom)
# חפש בבלוג זה
# רשומות פופולריות
# Skincare לשדרוגי איפור, עיניים ושפתיים.
# למה כדאי לקנות את הקונסילר בארץ?
# איך זה עובד?
# FA03 סקירת מוצר
# למה כדאי לקנות את הקונסילר בארץ?
# 3.7.17 - הקונצנזוס סביב מראה איפור - קונסילר
# 1.7.17 - איך להתאפר כמו אודרי הפבורן?
# אני מזהירה מראש, הקונסילר הזה ממכר...
# מה צריך לעשות בשביל שהקונסילר יצליח?
# קונסילרים מכילים פיגמנטים, שתפקידם להעניק לעור מראה חי וזוהר. לכן, על מנת להשתמש נכון בקונסילר עלינו לדעת להשתמש בו בצורה הנכונה.
# 2.7.17 - כל הדברים שרצית לדעת על מייקאפ
# מייקאפ הינו מוצר הנצרך בכל בית, ולכן חשוב לדעת עליו הכל. ריכזנו את כל מה שצריך לדעת כדי לדעת לאפר את עצמכן בצורה נכונה.
# על מנת להשתמש בכפתור אהבתי עליכם להיות מחוברים או להרשם.
# בושם זה נחמד, אבל כשזה נוגע לבשמים - עדיף להשתמש בבושם עדין שלא יכביד ולא ישעמם.
# על מנת להשתמש בכפתור אהבתי עליכם להיות מחוברים או להרשם.
# הבחורה הזו יודעת לעשות איפור!!!!!
# לשים לב מה היא משתמשת (למרות שאני לא רואה איפור שלה).
# היא משתמשת במברשת מייקאפ. אני לא בטוחה שזה יעזור, אני משתמשת במברשת מייקאפ בשביל להסתיר אזורים בעייתיים כמו הקמטוטים סביב העיניים, אבל אין ספק שמייקאפ זה חלק בלתי נפרד מהמראה.
# שמתי לב שהמברשות של בובי בראון יותר מעודנות.
# אני מאמינה שמייקאפ זה מוצר הנצרך בכל בית.
# יש לי מייקאפ של בובי בראון, עם מברשת מייקאפ גדולה וצפופה.
# יש לי מברשת מייקאפ שטוחה (פחות קטנה ממברשת מייקאפ גדולה אחרת).
# אני משתמשת במברשת מייקאפ של מאק (האהובה עלי במיוחד).
# יש לי גם צללית של בובי בראון (שהיא יקרה באופן יחסי).
# הבעיה עם המברשת היא שהיא צולעת עם הקצה, ולכן, אני משתמשת במברשת מייקאפ קטנה (במקום במברשת פודרה גדולה).
# אני לא אוהבת את המברשות של מאק, כי הן גדולות עבורי (אני רגילה למברשות זולות יותר).
# המברשת של בובי היא מברשת להנחת צלליות, ולכן אני משתמשת במברשת פודרה.
# יש לי מברשת הנחה גדולה של מאק (מס' 172, אם אני זוכרת נכון...).
# אני לא אוהבת מברשת מייקאפ קטנה וצפופה.
# מבחינת גודל, אני משתמשת במברשת של מייקאפ פודרה (אם אני זוכרת נכון...)
# המברשת שאני משתמשת בה היא מברשת מייקאפ של בובי בראון.
# אני משתמשת במברשת מייקאפ של

# %% [markdown]
# # dataset

# %%
import datasets
data = datasets.load_dataset('LevMuchnik/SupremeCourtOfIsrael')
# Out:
# Found cached dataset parquet (/home/user/.cache/huggingface/datasets/LevMuchnik___parquet/LevMuchnik--SupremeCourtOfIsrael-7f46ab7220db2581/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data['train'][0]['FileName']#['text']
# Out:
# '03058560_07V.txt'

# %%
type(data)
# Out:
# datasets.dataset_dict.DatasetDict

# %%
inputs=tokenizer(data['train'][0]['text'],return_tensors='pt',truncation=True)
inputs={k:v.to('cuda') for k,v in inputs.items()}
inputs
# Out:
# {'input_ids': tensor([[  203,   203,   203,  ...,  1319,   348, 21579]], device='cuda:0'),
#  'attention_mask': tensor([[1, 1, 1,  ..., 1, 1, 1]], device='cuda:0')}

# %%
import torch
with torch.no_grad():
    out=model(**inputs)
out.keys()
# Out:
# odict_keys(['logits', 'past_key_values'])

# %%
torch.stack(out.past_key_values[-1]).mean(axis=[0,1,2,3]).shape#.mean(axis=2).shape
# Out:
# torch.Size([128])

# %%
len(data['train'])
# Out:
# 751194

# %%
cut_data=data['train']#[:1000]

# %%
embeddings=[]

# %%
from tqdm.notebook import tqdm

# %%
with torch.no_grad():
    for d in tqdm(cut_data['text']):
        inputs=tokenizer(d,return_tensors='pt',truncation=True)
        inputs={k:v.to('cuda') for k,v in inputs.items()}
        out=model(**inputs)
        out=torch.stack(out.past_key_values[-1]).mean(axis=[0,1,2,3]).to('cpu')
        #out.to('cpu')
        embeddings.append(out)

# %%
embeddings=torch.stack(embeddings)#.to('cpu')
embeddings.shape
# Out:
# torch.Size([1000, 128])

# %%
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

# %% [markdown]
# # test

# %%
test_text="שוחד, מרמה והפרת אמונים"

# %%
inputs=tokenizer(test_text,return_tensors='pt',truncation=True)
inputs={k:v.to('cuda') for k,v in inputs.items()}
inputs
# Out:
# {'input_ids': tensor([[  287,  1718,    16,   718,   453,  9015,   282, 19900]],
#         device='cuda:0'),
#  'attention_mask': tensor([[1, 1, 1, 1, 1, 1, 1, 1]], device='cuda:0')}

# %%
out=model(**inputs)
out=torch.stack(out.past_key_values[-1]).mean(axis=[0,1,2,3]).to('cpu').detach()

_,idx=index.search(out[None],3)

# %%
print(cut_data['text'][idx[0][0]])
# Out:
# בבית המשפט העליון בירושלים בשבתו כבית משפט גבוה לצדק
#
#
#
#
#
#
#
# בג"ץ  6135/97
#
#
#
# בפני:
# כבוד
# השופט א' מצא
#
#
#
#
#
#
#
#
#
#
#
# העותר
# :
# אסמאעיל
# שבלי
#
#
#
#
#
#
#
#
#
#
#
#                    נגד
#
#
#
#
#
#
#
#
#
#
#
# המשיבים
# :
# 1.
# שר הפנים
#
#
#
#                                                       2.
# עלי שבלי, ראש המועצה המקומית שבלי
#
#
#
#
#
#
#
#
#
#
#
# צו על-תנאי
#
#
#
#
#
#
#
# על יסוד עתירה זו שהובאה היום לפני בית משפט זה, מצווה
# בית-המשפט כי ייצא מלפניו צו על תנאי המכוון על המשיב 1 והמורה לו להתייצב וליתן
# טעם מדוע לא יורה למשיב 2 להחזיר כספים שנטל מקופת המועצה המקומית לשימושו האישי,
# ומדוע לא ימנה צוות חקירה לחקור בפרשת מעילה בכספי הציבור על ידי משיב 2, אשר
# תפרסם מסקנותיה בפומבי ותשקול אפשרות הדחתו מתפקידו של המשיב 2; וכן צו על תנאי
# המכוון אל המשיב 2 והמורה לו להתייצב וליתן טעם מדוע לא ישיב למועצה מקומית שבלי
# כספים שנטל הימנה לצורך מימון הליכים משפטיים אישיים ופרעון חוב פסוק אישי.
#
#
#
#
#
#
#
# המשיבים יגישו תשובתם אם רנוצם בכך תוך 30 ימים מיום המצאת
# כתב זה, לבית-המשפט ולבעלי-הדין ישירות.
#
#
#
#
#
#
#
# ניתן היום, י"ד בתשרי
# תשנ"ח (15.10.97)
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                 שמריהו
# כהן
#
#
#
#                                                                                                 מזכיר
# ראשי
#
#
#
# העתק
# מתאים למקור
#
#
#
# שמריהו
# כהן - מזכיר ראשי
#
#
#
# 97061350.
# F02

# %%
cut_data.keys()
# Out:
# dict_keys(['case_id', 'download_time', 'number_of_case_documents', 'file_name', 'Id', 'CaseId', 'VerdictDt', 'CreatedDate', 'CaseNum', 'CaseDesc', 'Pages', 'Path', 'CaseName', 'FileName', 'DocName', 'Year', 'TypeCode', 'Type', 'Technical', 'CodeVolume', 'document_hash', 'text', 'html_title', 'VerdictsDt', 'meta_case_nm', 'meta_sec_appeal', 'meta_side_ty', 'meta_verdict_file_nm', 'meta_judge', 'meta_mador_nm', 'meta_side_nm', 'meta_verdict_dt', 'meta_case_dt', 'meta_verdict_nbr', 'meta_ProgId', 'meta_is_technical', 'meta_judge_nm_last', 'meta_case_nbr', 'meta_verdict_ty', 'meta_lawyer_nm', 'meta_judge_nm_first', 'meta_verdict_pages', 'meta_inyan_nm', 'meta_court_nm'])
